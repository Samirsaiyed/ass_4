# %% [markdown]
# # Assignment - 4

# %% [markdown]
# 1. What exactly is []?
#
# Ans: The empty list represented by [] is a list that contains no items.

# %% [markdown]
# 2. In a list of values stored in a variable called spam, how would you assign the value &#39;hello&#39; as the
# third value? (Assume [2, 4, 6, 8, 10] are in spam.)
#
# Ans: spam[2] = 'hello'

# %%
spam = [2,4,6,8,10]
print(spam)
spam[2] = 'hello'
print(spam)
# Out:
# [2, 4, 6, 8, 10]
# [2, 4, 'hello', 8, 10]

# %% [markdown]
# Let&#39;s pretend the spam includes the list [&#39;a&#39;, &#39;b&#39;, &#39;c&#39;, &#39;d&#39;] for the next three queries.

# %% [markdown]
# 3. What is the value of spam[int(int(&#39;3&#39; * 2) / 11)]?
#
# Ans: 'd' = lists support negative indexing. hence spam[-1] returns 'd'

# %%
spam = ['a','b','c','d']
print('spam[-1] =',spam[-1])
# Out:
# spam[-1] = d

# %% [markdown]
# 5. What is the value of spam[:2]?

# %% [markdown]
# Ans: spam[:2] returns all elements in the list spam from 0 to 2 excluding 2

# %%
print(spam)
print(spam[:2])
# Out:
# ['a', 'b', 'c', 'd']
# ['a', 'b']

# %% [markdown]
# Let&#39;s pretend bacon has the list [3.14, &#39;cat,&#39; 11, &#39;cat,&#39; True] for the next three questions.

# %% [markdown]
# 6. What is the value of bacon.index(&#39;cat&#39;)?

# %% [markdown]
# Ans: The value of bacon.index('cat') is 1

# %%
bacon = [3.14,'cat',11,'cat',True]
print("bacon.index('cat') =",bacon.index('cat'))
# Out:
# bacon.index('cat') = 1

# %% [markdown]
# 7. How does bacon.append(99) change the look of the list value in bacon?

# %% [markdown]
# Ans: The append method adds new elements to the end of the list

# %%
print(bacon)
bacon.append(99)
print(bacon)
# Out:
# [3.14, 'cat', 11, 'cat', True]
# [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# 8. How does bacon.remove(&#39;cat&#39;) change the look of the list in bacon?

# %% [markdown]
# Ans: The remove method removes the first occurence of the element in the list

# %%
print(bacon)
bacon.remove('cat')
print(bacon)
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]
# [3.14, 11, 'cat', True, 99]

# %% [markdown]
# 9. What are the list concatenation and list replication operators?

# %% [markdown]
# Ans: The operator for list concatination is + , while the operator for replication is * .

# %%
l1 = ['NLP' , 'AI' , 'ML' ]
l2 = ['DL' , 'CV' , 'SVN' ]
print(l1 + l2)
print(l2*2)
# Out:
# ['NLP', 'AI', 'ML', 'DL', 'CV', 'SVN']
# ['DL', 'CV', 'SVN', 'DL', 'CV', 'SVN']

# %% [markdown]
# 10. What is difference between the list methods append() and insert()?

# %% [markdown]
# Ans: While append() will add values only to the end of a list  , insert() can add them anywhere in the list.

# %%
l = [1,2,3,4,5]
l.append(6)
print(l)
l.insert(3,'Sam')
print(l)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 'Sam', 4, 5, 6]

# %% [markdown]
# 11. What are the two methods for removing items from a list?

# %% [markdown]
# Ans: The del statement and the remove() method are two ways to remove values from a list

# %% [markdown]
# 12. Describe how list values and string values are identical.

# %% [markdown]
# Ans: Both lists and string can be passed to len() function, have indexs and slices, be used in for loops, be concatenated to replicated , and be used with the in and not in operators.

# %% [markdown]
# 13. What&#39;s the difference between tuples and lists?

# %% [markdown]
# Ans: Lists are Mutable, Indexable and Slicable . they can have value added, removed, or changed. Tuples are Immutable but Indexable and Slicable. the tuple values cannot be changed at all. Also, tuples are using parentheses, (), while lists use the squre brackets,[].

# %% [markdown]
# 14. How do you type a tuple value that only contains the integer 42?

# %% [markdown]
# Ans: (42,)

# %%
t1 = (42)
t2 = (42,)
print(type(t1))
print(type(t2))
# Out:
# <class 'int'>
# <class 'tuple'>

# %% [markdown]
# 15. How do you get a list value&#39;s tuple form? How do you get a tuple value&#39;s list form?

# %% [markdown]
# Ans: The tuple() and list() functions, respectively are used to converta list to tuple and vice versa

# %% [markdown]
# 16. Variables that &quot;contain&quot; list values are not necessarily lists themselves. Instead, what do they
# contain?

# %% [markdown]
# Ans: They contain references to list values.

# %% [markdown]
# 17. How do you distinguish between copy.copy() and copy.deepcopy()?

# %% [markdown]
# Ans: The copy.copy() function will do a shallow copy of a list, while the copy.deepcopy() function will do a deep copy a list. that is , only copu.deepcopy() will duplicate any lists inside the list.
